# %% [markdown]
# # import pandas as pd   匯入 pandas，並取別名為 pd，方便後續使用。
#
# # df = pd.read_csv("各鄉鎮市區人口密度.csv")  使用 pd.read_csv() 讀取名為「各鄉鎮市區人口密度.csv」的檔案。
# 讀取後的資料會存成一個 DataFrame 物件 df，每一列對應檔案中的一筆資料，每一欄對應檔案中的一個欄位。
#
# # df1 = df.rename(columns={"statistic_yyy":"統計年",
#                    "site_id":"區域別",
#                    "people_total":"年底人口數",
#                    "area":"土地面積",
#                    "population_density":"人口密度"
#                    })
# # df1
# 使用 rename() 方法，將原本英文的欄位名稱改成中文。
# columns={...} 參數是一個字典，左邊是原欄位名，右邊是新欄位名。
# 產生一個新的 DataFrame df1，其欄位名稱已經是中文，方便閱讀與後續分析。

# %%
import pandas as pd   

df = pd.read_csv("各鄉鎮市區人口密度.csv")
df1 = df.rename(columns={"statistic_yyy":"統計年",
                   "site_id":"區域別",
                   "people_total":"年底人口數",
                   "area":"土地面積",
                   "population_density":"人口密度"
                   })
df1
# Out:
#      統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
#       人口密度
# 0     人口密度
# 1    23835
# 2    23747
# 3    20532
# 4    38956
# ..     ...
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN
#
# [376 rows x 5 columns]

# %%
df.columns = ["統計年","區域別","年底人口數","土地面積","人口密度"]
df
# Out:
#      統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
#       人口密度
# 0     人口密度
# 1    23835
# 2    23747
# 3    20532
# 4    38956
# ..     ...
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN
#
# [376 rows x 5 columns]

# %%
df2 = df.drop(["統計年"],axis=1)
df2
# Out:
#                                                    區域別   年底人口數     土地面積   人口密度
# 0                                                  區域別   年底人口數     土地面積   人口密度
# 1                                               新北市板橋區  551480  23.1373  23835
# 2                                               新北市三重區  387484   16.317  23747
# 3                                               新北市中和區  413590   20.144  20532
# 4                                               新北市永和區  222585   5.7138  38956
# ..                                                 ...     ...      ...    ...
# 371                                                NaN     NaN      NaN    NaN
# 372                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN    NaN
# 373  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN    NaN
# 374           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN    NaN
# 375           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN    NaN
#
# [376 rows x 4 columns]

# %%
df3 = df2.dropna(axis=0)
df3
# Out:
#         區域別   年底人口數     土地面積   人口密度
# 0       區域別   年底人口數     土地面積   人口密度
# 1    新北市板橋區  551480  23.1373  23835
# 2    新北市三重區  387484   16.317  23747
# 3    新北市中和區  413590   20.144  20532
# 4    新北市永和區  222585   5.7138  38956
# ..      ...     ...      ...    ...
# 366  連江縣北竿鄉    2360      9.9    238
# 367  連江縣莒光鄉    1624      4.7    346
# 368  連江縣東引鄉    1352      3.8    356
# 369    東沙群島      …      2.38     …
# 370    南沙群島      …    0.5045     …
#
# [371 rows x 4 columns]

# %%
df4 = df3.drop(index=0)
df4
# Out:
#         區域別   年底人口數     土地面積   人口密度
# 1    新北市板橋區  551480  23.1373  23835
# 2    新北市三重區  387484   16.317  23747
# 3    新北市中和區  413590   20.144  20532
# 4    新北市永和區  222585   5.7138  38956
# 5    新北市新莊區  416524  19.7383  21102
# ..      ...     ...      ...    ...
# 366  連江縣北竿鄉    2360      9.9    238
# 367  連江縣莒光鄉    1624      4.7    346
# 368  連江縣東引鄉    1352      3.8    356
# 369    東沙群島      …      2.38     …
# 370    南沙群島      …    0.5045     …
#
# [370 rows x 4 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 1 to 370
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域別     370 non-null    object
#  1   年底人口數   370 non-null    object
#  2   土地面積    370 non-null    object
#  3   人口密度    370 non-null    object
# dtypes: object(4)
# memory usage: 14.5+ KB

# %%
# df4['年底人口數'].astype(int) #無法轉換
def string_to_int(value:str):
    try:
        v = int(value)
        return v
    except Exception:
        return 0
    
df4["年底人口數"] = df4["年底人口數"].map(string_to_int)
df4["人口密度"] = df4["人口密度"].apply(string_to_int)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 1 to 370
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域別     370 non-null    object
#  1   年底人口數   370 non-null    int64
#  2   土地面積    370 non-null    object
#  3   人口密度    370 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 14.5+ KB

# %%
df4['土地面積'] = df4['土地面積'].astype(float)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 370 entries, 1 to 370
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   區域別     370 non-null    object
#  1   年底人口數   370 non-null    int64
#  2   土地面積    370 non-null    float64
#  3   人口密度    370 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 14.5+ KB

# %%
df4
# Out:
#         區域別   年底人口數     土地面積   人口密度
# 1    新北市板橋區  551480  23.1373  23835
# 2    新北市三重區  387484  16.3170  23747
# 3    新北市中和區  413590  20.1440  20532
# 4    新北市永和區  222585   5.7138  38956
# 5    新北市新莊區  416524  19.7383  21102
# ..      ...     ...      ...    ...
# 366  連江縣北竿鄉    2360   9.9000    238
# 367  連江縣莒光鄉    1624   4.7000    346
# 368  連江縣東引鄉    1352   3.8000    356
# 369    東沙群島       0   2.3800      0
# 370    南沙群島       0   0.5045      0
#
# [370 rows x 4 columns]

# %%
def split_words(v:str):
    if len(v) == 6:
        return v[:3]
    else:
        return v

df4["縣市"] = df4['區域別'].map(split_words)

# %%
def split_words(v:str):
    if len(v) == 6:
        return v[:3]
    else:
        return v
df4['縣市']=df4["區域別"].map(split_words)

# %%
def split_area(v:str):
    if len(v) == 6:
        return v[-3:]
    else:
        return v
df4['區域別'] = df4['區域別'].map(split_area)

# %%
df4
# Out:
#       區域別   年底人口數     土地面積   人口密度    縣市
# 1     板橋區  551480  23.1373  23835   新北市
# 2     三重區  387484  16.3170  23747   新北市
# 3     中和區  413590  20.1440  20532   新北市
# 4     永和區  222585   5.7138  38956   新北市
# 5     新莊區  416524  19.7383  21102   新北市
# ..    ...     ...      ...    ...   ...
# 366   北竿鄉    2360   9.9000    238   連江縣
# 367   莒光鄉    1624   4.7000    346   連江縣
# 368   東引鄉    1352   3.8000    356   連江縣
# 369  東沙群島       0   2.3800      0  東沙群島
# 370  南沙群島       0   0.5045      0  南沙群島
#
# [370 rows x 5 columns]

# %%
df5 = df4.reindex(columns=["區域別","年底人口數","土地面積","人口密度","縣市"])
df6 = df5.set_index("區域別")

# %%
df6.to_excel("各鄉鎮市區人口密度.xlsx", index=True)
