# %% [markdown]
# https://www.perplexity.ai/search/541099c9-ea3f-4aaa-98b2-53af4156f3cc
#
# 需要安裝jinja2套件

# %%
#Styler.format()
#Style.format_index()
#Style.relabel_index()

import pandas as pd
import numpy as np

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]})
type(df.style)

display(df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230

# %%
#Styler.format()
#Style.format_index()
#Style.relabel_index()

import pandas as pd
import numpy as np 

df = pd.DataFrame({
    "strings": ["Adam", "Mike"],
    "ints": [1, 3],
    "floats": [1.123, 1000.23]
})
type(df.style)

display(df)
s = df.style\
.format(precision=3, thousands=",", decimal='.')\
.format_index(str.upper,axis=1)\
.relabel_index(["列1","列2"])
# Out:
#   strings  ints    floats
# 0    Adam     1     1.123
# 1    Mike     3  1000.230

# %% [markdown]
# weather_df 這個 DataFrame 的結構如下：
# # weather_df = pd.DataFrame(np.random.rand(600, 2)*5
# 類型：pandas.core.frame.DataFrame
# # index=pd.date_range(start="2024-01-01", periods=600),
# 索引：DatetimeIndex，總共有 600 筆資料，日期範圍從 2024-01-01 到 2025-08-22，頻率為每日（D）
# # columns=["東京", "台北"]) 欄位數：2 個（「東京」與「台北」）
# # weather_df.info()
# 每個欄位的資料型態：float64
# 每個欄位的非空值數量：600（無缺漏值）
# 記憶體用量：約 14.1 KB

# %%
weather_df = pd.DataFrame(np.random.rand(600, 2)*5,
                          index=pd.date_range(start="2024-01-01", periods=600),
                          columns=["東京", "台北"])
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 600 entries, 2024-01-01 to 2025-08-22
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   東京      600 non-null    float64
#  1   台北      600 non-null    float64
# dtypes: float64(2)
# memory usage: 14.1 KB

# %%
#因為索引是datetime的資料
weather_df.loc["2024-01-10":"2024-01-30"]
weather_df.loc["2024-01"]
weather_df.loc["2024"]
# Out:
#                   東京        台北
# 2024-01-01  1.485989  3.070175
# 2024-01-02  2.065660  2.659445
# 2024-01-03  0.289463  0.619106
# 2024-01-04  4.937093  3.350273
# 2024-01-05  3.410494  4.756682
# ...              ...       ...
# 2024-12-27  2.383169  4.302283
# 2024-12-28  0.605030  0.318564
# 2024-12-29  3.448069  3.172111
# 2024-12-30  3.922903  1.476668
# 2024-12-31  1.091934  4.423820
#
# [366 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['東京'],label='Tokyyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['台北'],label='Taiepi',linestyle='',marker='.')
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
axes.plot(weather_df.index,weather_df['東京'],label='Tokyyo',linestyle='',marker='.')
axes.plot(weather_df.index,weather_df['台北'],label='Taiepi',linestyle='',marker='.')
plt.show()
plt.close()

# %%
figure = plt.figure(figsize=(10,6))
axes = figure.add_subplot(1,1,1)
weather_df.plot(ax=axes,linestyle='',marker='.')
plt.show()
plt.close()
# Out:
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 26481 (\N{CJK UNIFIED IDEOGRAPH-6771}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 20140 (\N{CJK UNIFIED IDEOGRAPH-4EAC}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21488 (\N{CJK UNIFIED IDEOGRAPH-53F0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 21271 (\N{CJK UNIFIED IDEOGRAPH-5317}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# 建立一個隨機的天氣資料表格（DataFrame），模擬東京與台北 10 天的降雨數值。
# 定義一個 rain_condition 函式，根據數值將天氣狀況分為「乾燥」、「小雨」、「大雨」。
# # np.random.rand(10,2)*5 產生 10x2 的隨機數矩陣，數值範圍是 0~5（模擬降雨量）。
# # index=pd.date_range(start="2024-01-01", periods=10) 設定索引為 2024/01/01 起連續 10 天。
# # columns=["東京", "台北"] 欄位名稱為「東京」和「台北」。
# 輸入 v（降雨量數值）
# # if v<1.75: return "乾燥"
# 小於 1.75：回傳「乾燥」
# # elif v<2.75: return "小雨"
# 介於 1.75 ~ 2.75：回傳「小雨」
# # else: return "大雨"
# 大於等於 2.75：回傳「大雨」

# %%
weather_df = pd.DataFrame(np.random.rand(10,2)*5,
                        index=pd.date_range(start="2024-01-01", periods=10),
                        columns=["東京", "台北"])
def rain_condition(v):
    if v<1.75:
        return "乾燥"
    elif v<2.75:
        return "小雨"
    else:
        return "大雨"
def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_aad90">
#   <caption>天氣狀況</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aad90_level0_col0" class="col_heading level0 col0" >東京</th>
#       <th id="T_aad90_level0_col1" class="col_heading level0 col1" >台北</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aad90_level0_row0" class="row_heading level0 row0" >2024-01-01 00:00:00</th>
#       <td id="T_aad90_row0_col0" class="data row0 col0" >小雨</td>
#       <td id="T_aad90_row0_col1" class="data row0 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_aad90_level0_row1" class="row_heading level0 row1" >2024-01-02 00:00:00</th>
#       <td id="T_aad90_row1_col0" class="data row1 col0" >小雨</td>
#       <td id="T_aad90_row1_col1" class="data row1 col1" >大雨</td>
#     </tr>
#     <tr>
#       <th id="T_aad90_level0_row2" class="row_heading level0 row2" >2024-01-03 00:00:00</th>
# ...

# %% [markdown]
# 1. make_pretty 函式
# 這是一個自訂的函式，專門用來美化 pandas DataFrame 的 Styler 物件。它會依序進行以下操作：
# # styler.set_caption("天氣狀況")
# 設定表格標題為「天氣狀況」。
# # styler.format(rain_condition)
# 使用 rain_condition 這個格式化函式（或字典）來格式化 DataFrame 的內容。這通常用來美化數值或自訂顯示方式。
# # styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
# 格式化索引（假設索引是 datetime 型別），將日期顯示為「年/月/日 星期幾」的格式。例如「2024/01/01 Monday」。
# # styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="PuBuGn")
# 對整個表格（axis=None）套用背景色漸層。顏色範圍由 1 到 5，使用 "PuBuGn" 色譜。這會根據數值自動著色，提高可視化效果。
# # return styler
# 回傳美化後的 Styler 物件。
# 2. # s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
# # weather_df.loc['2024-01-01':'2024-01-07']
# 從 weather_df DataFrame 選取 2024 年 1 月 1 日到 1 月 7 日這段期間的資料。
# # .style
# 取得這個切片的 Styler 物件，準備進行樣式設定。
# # .pipe(make_pretty)
# 利用 pipe 方法，把 Styler 物件傳給 make_pretty 函式進行美化。
# # s
# 最後將美化後的 Styler 物件存到變數 s，可以用於 Jupyter Notebook 或輸出為 HTML。

# %%
def make_pretty(styler):
    styler.set_caption("天氣狀況")
    styler.format(rain_condition)
    styler.format_index(formatter=lambda v:v.strftime("%Y/%m/%d %A"))
    styler.background_gradient(axis=None,vmin=1,vmax=5,cmap="PuBuGn")
    return styler

s = weather_df.loc['2024-01-01':'2024-01-07'].style.pipe(make_pretty)
s
# Out:
# <style type="text/css">
# #T_b54e1_row0_col0 {
#   background-color: #9dbad9;
#   color: #000000;
# }
# #T_b54e1_row0_col1 {
#   background-color: #015948;
#   color: #f1f1f1;
# }
# #T_b54e1_row1_col0 {
#   background-color: #dcd8ea;
#   color: #000000;
# }
# #T_b54e1_row1_col1 {
#   background-color: #0c8495;
#   color: #f1f1f1;
# }
# #T_b54e1_row2_col0, #T_b54e1_row5_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b54e1_row2_col1 {
#   background-color: #a3bcda;
#   color: #000000;
# }
# #T_b54e1_row3_col0 {
#   background-color: #01756f;
#   color: #f1f1f1;
# }
# #T_b54e1_row3_col1 {
#   background-color: #519ec8;
#   color: #f1f1f1;
# }
# #T_b54e1_row4_col0 {
#   background-color: #2b8db5;
#   color: #f1f1f1;
# }
# #T_b54e1_row4_col1 {
#   background-color: #ded9eb;
#   color: #000000;
# }
# #T_b54e1_row5_col0 {
#   background-color: #66a9cf;
#   color: #f1f1f1;
# }
# #T_b54e1_row6_col0 {
#   background-color: #014a39;
#   color: #f1f1f1;
# }
# ...
